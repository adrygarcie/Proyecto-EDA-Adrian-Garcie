# %%
import pandas as pd

# %%
df = pd.read_csv('data/scraped_earthquakes.csv')

# %%
df
# Out:
#               Date & Time UTC  Lat. degrees  Lon. degrees  Depth km  \
# 0       2025-04-01 23:59:55.8        26.467       128.814        10
# 1       2025-04-01 23:59:55.0        26.210       128.630        10
# 2       2025-04-01 23:59:54.7        26.118       128.556        10
# 3       2025-04-01 23:59:54.1        26.060       128.500        10
# 4       2025-04-01 23:59:53.7        26.020       128.510        10
# ...                       ...           ...           ...       ...
# 421314  2019-06-09 05:00:15.1        53.329         6.833         1
# 421315  2019-06-09 05:00:15.1        53.329         6.833         1
# 421316  2019-06-09 05:00:15.1        53.329         6.833         1
# 421317  2019-06-09 05:00:15.1        53.329         6.833         1
# 421318  2019-06-09 05:00:15.0        53.320         6.770         3
#
#                        Region    Type A/M  Magnitude Network
# 0       RYUKYU ISLANDS, JAPAN  origin   A        5.1     SC4
# ...
